# %%
import tpn.util as tu
import tpn.visualstudio as vs
import tpn.visualstudio.numpy as np

# %%
#import tpn.visualstudio.templates as vst
#print(vst.gen_guids())

# %%
print(tu.get_source(np.NumpyProject))
# Out:
# class NumpyProject(Project):
#     name = 'numpy'
#     version = '1.9.2'
#     major = '1'
#     minor = '9'
#     micro = '2'
#     build = '0'
#     #cpp_exceptions = True
#
#     exclude_files = [
#         'apple_sgemv_fix.c',
#     ]
#     relative_src_dirs = [
#         'numpy',
#         'build\\src.win-amd64-3.3\\numpy',
#         #'build\\src.win-amd64-3.3\\numpy\\core\\src',
#         #'build\\src.win-amd64-3.3\\numpy\\linalg',
#         #'build\\src.win-amd64-3.3\\numpy\\fft',
#         #'build\\src.win-amd64-3.3\\numpy\\random',
#     ]
#     relative_src_dirs = [ 'numpy' ]
#     include_dirs = [
#         'numpy\\core\\include',
#         'build\\src.win-amd64-3.3\\numpy\\core\\include',
#         'build\\src.win-amd64-3.3\\numpy\\core\\include\\numpy',
#         'numpy\\core\\src\\private',
#         'numpy\\core\\src',
#         'numpy\\core',
#         'numpy\\core\\src\\npymath',
#         'numpy\\core\\src\\multiarray',
#         'numpy\\core\\src\\umath',
#         'numpy\\core\\src\\npysort',
#         'build\\src.win-amd64-3.3\\numpy\\core\\include',
#         'build\\src.win-amd64-3.3\\numpy\\core\\src\\private',
#         'build\\src.win-amd64-3.3\\numpy\\core\\src',
#         'build\\src.win-amd64-3.3\\numpy\\core',
#         'build\\src.win-amd64-3.3\\numpy\\core\\src\\npymath',
#         'build\\src.win-amd64-3.3\\numpy\\core\\src\\multiarray',
#         'build\\src.win-amd64-3.3\\numpy\\core\\src\\umath',
#         'build\\src.win-amd64-3.3\\numpy\\core\\src\\npysort',
#     ]
#
#     guid = '{9D966218-0FD0-11E5-B4A4-8863DFCA3C40}'
#     source_filterdef_guid = '{9D966219-0FD0-11E5-A785-8863DFCA3C40}'
#     include_filterdef_guid = '{9D96621A-0FD0-11E5-A2A8-8863DFCA3C40}'
#     other_filterdef_guid = '{9D96621B-0FD0-11E5-A79E-8863DFCA3C40}'
#     python_filterdef_guid = '{9D96621C-0FD0-11E5-9053-8863DFCA3C40}'
#     cython_filterdef_guid = '{9D96621D-0FD0-11E5-B424-8863DFCA3C40}'
#     resource_filterdef_guid = '{9D96621E-0FD0-11E5-BAD2-8863DFCA3C40}'
#
#     compile_defines = {
#         #'PYODBC_UNICODE_WIDTH': '2',
#     }
#
#     resource_defines = {
#         'NUMPY_VERSION': version,
#         'NUMPY_MAJOR': major,
#         'NUMPY_MINOR': minor,
#         'NUMPY_MICRO': micro,
#         'NUMPY_BUILD': build,
#     }
#
#     def exclude_custom(self, root, filename):
#         return (
#             'f2py' in root or
#             'test' in root or
#             'tests' in root or
#             'distutils' in root or
#             'onefile' in filename or
#             'wrapmodule' in filename
#         )

# %%
p = np.NumpyProject()
p.load()

# %%
print(p.vcxproj)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <Project DefaultTargets="Build" ToolsVersion="4.0" xmlns="http://schemas.microsoft.com/developer/msbuild/2003">
#   <ItemGroup Label="ProjectConfigurations">
#     <ProjectConfiguration Include="Debug|Win32">
#       <Configuration>Debug</Configuration>
#       <Platform>Win32</Platform>
#     </ProjectConfiguration>
#     <ProjectConfiguration Include="Debug|x64">
#       <Configuration>Debug</Configuration>
#       <Platform>x64</Platform>
#     </ProjectConfiguration>
#     <ProjectConfiguration Include="PGInstrument|Win32">
#       <Configuration>PGInstrument</Configuration>
#       <Platform>Win32</Platform>
#     </ProjectConfiguration>
#     <ProjectConfiguration Include="PGInstrument|x64">
#       <Configuration>PGInstrument</Configuration>
#       <Platform>x64</Platform>
#     </ProjectConfiguration>
#     <ProjectConfiguration Include="PGUpdate|Win32">
#       <Configuration>PGUpdate</Configuration>
#       <Platform>Win32</Platform>
#     </ProjectConfiguration>
#     <ProjectConfiguration Include="PGUpdate|x64">
#       <Configuration>PGUpdate</Configuration>
#       <Platform>x64</Platform>
#     </ProjectConfiguration>
#     <ProjectConfiguration Include="Release|Win32">
#       <Configuration>Release</Configuration>
#       <Platform>Win32</Platform>
#     </ProjectConfiguration>
#     <ProjectConfiguration Include="Release|x64">
#       <Configuration>Release</Configuration>
#       <Platform>x64</Platform>
#     </ProjectConfiguration>
#   </ItemGroup>
#   <PropertyGroup Label="Globals">
#     <ProjectGuid>{9D966218-0FD0-11E5-B4A4-8863DFCA3C40}</ProjectGuid>
#     <RootNamespace>numpy</RootNamespace>
#     <Keyword>Win32Proj</Keyword>
#   </PropertyGroup>
#   <PropertyGroup Label="UserMacros">
#     <numpyDir>..\contrib\numpy</numpyDir>
#   </PropertyGroup>
#   <Import Project="$(VCTargetsPath)\Microsoft.Cpp.Default.props" />
#   <PropertyGroup Condition="'$(Configuration)|$(Platform)'=='PGUpdate|Win32'" Label="Configuration">
#     <ConfigurationType>DynamicLibrary</ConfigurationType>
#     <CharacterSet>NotSet</CharacterSet>
#     <WholeProgramOptimization>true</WholeProgramOptimization>
#   </PropertyGroup>
#   <PropertyGroup Condition="'$(Configuration)|$(Platform)'=='PGInstrument|Win32'" Label="Configuration">
#     <ConfigurationType>DynamicLibrary</ConfigurationType>
#     <CharacterSet>NotSet</CharacterSet>
#     <WholeProgramOptimization>true</WholeProgramOptimization>
#   </PropertyGroup>
#   <PropertyGroup Condition="'$(Configuration)|$(Platform)'=='Release|Win32'" Label="Configuration">
#     <ConfigurationType>DynamicLibrary</ConfigurationType>
#     <CharacterSet>NotSet</CharacterSet>
#     <WholeProgramOptimization>true</WholeProgramOptimization>
#   </PropertyGroup>
#   <PropertyGroup Condition="'$(Configuration)|$(Platform)'=='Debug|Win32'" Label="Configuration">
#     <ConfigurationType>DynamicLibrary</ConfigurationType>
#     <CharacterSet>NotSet</CharacterSet>
#   </PropertyGroup>
#   <PropertyGroup Condition="'$(Configuration)|$(Platform)'=='PGUpdate|x64'" Label="Configuration">
#     <ConfigurationType>DynamicLibrary</ConfigurationType>
#     <CharacterSet>NotSet</CharacterSet>
#     <WholeProgramOptimization>true</WholeProgramOptimization>
#   </PropertyGroup>
#   <PropertyGroup Condition="'$(Configuration)|$(Platform)'=='PGInstrument|x64'" Label="Configuration">
#     <ConfigurationType>DynamicLibrary</ConfigurationType>
#     <CharacterSet>NotSet</CharacterSet>
#     <WholeProgramOptimization>true</WholeProgramOptimization>
#   </PropertyGroup>
#   <PropertyGroup Condition="'$(Configuration)|$(Platform)'=='Release|x64'" Label="Configuration">
#     <ConfigurationType>DynamicLibrary</ConfigurationType>
#     <CharacterSet>NotSet</CharacterSet>
#     <WholeProgramOptimization>true</WholeProgramOptimization>
#   </PropertyGroup>
#   <PropertyGroup Condition="'$(Configuration)|$(Platform)'=='Debug|x64'" Label="Configuration">
#     <ConfigurationType>DynamicLibrary</ConfigurationType>
#     <CharacterSet>NotSet</CharacterSet>
#   </PropertyGroup>
#   <Import Project="$(VCTargetsPath)\Microsoft.Cpp.props" />
#   <ImportGroup Label="ExtensionSettings">
#   </ImportGroup>
#   <ImportGroup Condition="'$(Configuration)|$(Platform)'=='PGUpdate|Win32'" Label="PropertySheets">
#     <Import Project="$(UserRootDir)\Microsoft.Cpp.$(Platform).user.props" Condition="exists('$(UserRootDir)\Microsoft.Cpp.$(Platform).user.props')" Label="LocalAppDataPlatform" />
#     <Import Project="numpy.props" />
#     <Import Project="pyd.props" />
#     <Import Project="pgupdate.props" />
#   </ImportGroup>
#   <ImportGroup Condition="'$(Configuration)|$(Platform)'=='PGInstrument|Win32'" Label="PropertySheets">
#     <Import Project="$(UserRootDir)\Microsoft.Cpp.$(Platform).user.props" Condition="exists('$(UserRootDir)\Microsoft.Cpp.$(Platform).user.props')" Label="LocalAppDataPlatform" />
#     <Import Project="numpy.props" />
#     <Import Project="pyd.props" />
#     <Import Project="pginstrument.props" />
#   </ImportGroup>
#   <ImportGroup Condition="'$(Configuration)|$(Platform)'=='Release|Win32'" Label="PropertySheets">
#     <Import Project="$(UserRootDir)\Microsoft.Cpp.$(Platform).user.props" Condition="exists('$(UserRootDir)\Microsoft.Cpp.$(Platform).user.props')" Label="LocalAppDataPlatform" />
#     <Import Project="numpy.props" />
#     <Import Project="pyd.props" />
#   </ImportGroup>
#   <ImportGroup Condition="'$(Configuration)|$(Platform)'=='Debug|Win32'" Label="PropertySheets">
#     <Import Project="$(UserRootDir)\Microsoft.Cpp.$(Platform).user.props" Condition="exists('$(UserRootDir)\Microsoft.Cpp.$(Platform).user.props')" Label="LocalAppDataPlatform" />
#     <Import Project="numpy.props" />
#     <Import Project="numpy_debug.props" />
#     <Import Project="pyd_d.props" />
#     <Import Project="debug.props" />
#   </ImportGroup>
#   <ImportGroup Condition="'$(Configuration)|$(Platform)'=='PGUpdate|x64'" Label="PropertySheets">
#     <Import Project="$(UserRootDir)\Microsoft.Cpp.$(Platform).user.props" Condition="exists('$(UserRootDir)\Microsoft.Cpp.$(Platform).user.props')" Label="LocalAppDataPlatform" />
#     <Import Project="numpy.props" />
#     <Import Project="pyd.props" />
#     <Import Project="x64.props" />
#     <Import Project="pgupdate.props" />
#   </ImportGroup>
#   <ImportGroup Condition="'$(Configuration)|$(Platform)'=='PGInstrument|x64'" Label="PropertySheets">
#     <Import Project="$(UserRootDir)\Microsoft.Cpp.$(Platform).user.props" Condition="exists('$(UserRootDir)\Microsoft.Cpp.$(Platform).user.props')" Label="LocalAppDataPlatform" />
#     <Import Project="numpy.props" />
#     <Import Project="pyd.props" />
#     <Import Project="x64.props" />
#     <Import Project="pginstrument.props" />
#   </ImportGroup>
#   <ImportGroup Condition="'$(Configuration)|$(Platform)'=='Release|x64'" Label="PropertySheets">
#     <Import Project="$(UserRootDir)\Microsoft.Cpp.$(Platform).user.props" Condition="exists('$(UserRootDir)\Microsoft.Cpp.$(Platform).user.props')" Label="LocalAppDataPlatform" />
#     <Import Project="numpy.props" />
#     <Import Project="pyd.props" />
#     <Import Project="x64.props" />
#   </ImportGroup>
#   <ImportGroup Condition="'$(Configuration)|$(Platform)'=='Debug|x64'" Label="PropertySheets">
#     <Import Project="$(UserRootDir)\Microsoft.Cpp.$(Platform).user.props" Condition="exists('$(UserRootDir)\Microsoft.Cpp.$(Platform).user.props')" Label="LocalAppDataPlatform" />
#     <Import Project="numpy.props" />
#     <Import Project="numpy_debug.props" />
#     <Import Project="pyd_d.props" />
#     <Import Project="debug.props" />
#     <Import Project="x64.props" />
#   </ImportGroup>
#   <PropertyGroup Label="UserMacros" />
#   <PropertyGroup>
#     <_ProjectFileVersion>10.0.30319.1</_ProjectFileVersion>
#     <CodeAnalysisRuleSet Condition="'$(Configuration)|$(Platform)'=='Debug|Win32'">AllRules.ruleset</CodeAnalysisRuleSet>
#     <CodeAnalysisRules Condition="'$(Configuration)|$(Platform)'=='Debug|Win32'" />
#     <CodeAnalysisRuleAssemblies Condition="'$(Configuration)|$(Platform)'=='Debug|Win32'" />
#     <CodeAnalysisRuleSet Condition="'$(Configuration)|$(Platform)'=='Debug|x64'">AllRules.ruleset</CodeAnalysisRuleSet>
#     <CodeAnalysisRules Condition="'$(Configuration)|$(Platform)'=='Debug|x64'" />
#     <CodeAnalysisRuleAssemblies Condition="'$(Configuration)|$(Platform)'=='Debug|x64'" />
#     <CodeAnalysisRuleSet Condition="'$(Configuration)|$(Platform)'=='PGInstrument|Win32'">AllRules.ruleset</CodeAnalysisRuleSet>
#     <CodeAnalysisRules Condition="'$(Configuration)|$(Platform)'=='PGInstrument|Win32'" />
#     <CodeAnalysisRuleAssemblies Condition="'$(Configuration)|$(Platform)'=='PGInstrument|Win32'" />
#     <CodeAnalysisRuleSet Condition="'$(Configuration)|$(Platform)'=='PGInstrument|x64'">AllRules.ruleset</CodeAnalysisRuleSet>
#     <CodeAnalysisRules Condition="'$(Configuration)|$(Platform)'=='PGInstrument|x64'" />
#     <CodeAnalysisRuleAssemblies Condition="'$(Configuration)|$(Platform)'=='PGInstrument|x64'" />
#     <CodeAnalysisRuleSet Condition="'$(Configuration)|$(Platform)'=='PGUpdate|Win32'">AllRules.ruleset</CodeAnalysisRuleSet>
#     <CodeAnalysisRules Condition="'$(Configuration)|$(Platform)'=='PGUpdate|Win32'" />
#     <CodeAnalysisRuleAssemblies Condition="'$(Configuration)|$(Platform)'=='PGUpdate|Win32'" />
#     <CodeAnalysisRuleSet Condition="'$(Configuration)|$(Platform)'=='PGUpdate|x64'">AllRules.ruleset</CodeAnalysisRuleSet>
#     <CodeAnalysisRules Condition="'$(Configuration)|$(Platform)'=='PGUpdate|x64'" />
#     <CodeAnalysisRuleAssemblies Condition="'$(Configuration)|$(Platform)'=='PGUpdate|x64'" />
#     <CodeAnalysisRuleSet Condition="'$(Configuration)|$(Platform)'=='Release|Win32'">AllRules.ruleset</CodeAnalysisRuleSet>
#     <CodeAnalysisRules Condition="'$(Configuration)|$(Platform)'=='Release|Win32'" />
#     <CodeAnalysisRuleAssemblies Condition="'$(Configuration)|$(Platform)'=='Release|Win32'" />
#     <CodeAnalysisRuleSet Condition="'$(Configuration)|$(Platform)'=='Release|x64'">AllRules.ruleset</CodeAnalysisRuleSet>
#     <CodeAnalysisRules Condition="'$(Configuration)|$(Platform)'=='Release|x64'" />
#     <CodeAnalysisRuleAssemblies Condition="'$(Configuration)|$(Platform)'=='Release|x64'" />
#   </PropertyGroup>
#   <ItemDefinitionGroup Condition="'$(Configuration)|$(Platform)'=='Debug|Win32'">
#     <ClCompile>
#       <AdditionalIncludeDirectories>%(AdditionalIncludeDirectories)</AdditionalIncludeDirectories>
#     </ClCompile>
#   </ItemDefinitionGroup>
#   <ItemDefinitionGroup Condition="'$(Configuration)|$(Platform)'=='Debug|x64'">
#     <Midl>
#       <TargetEnvironment>X64</TargetEnvironment>
#     </Midl>
#     <ClCompile>
#       <AdditionalIncludeDirectories>%(AdditionalIncludeDirectories)</AdditionalIncludeDirectories>
#     </ClCompile>
#   </ItemDefinitionGroup>
#   <ItemDefinitionGroup Condition="'$(Configuration)|$(Platform)'=='Release|Win32'">
#     <ClCompile>
#       <AdditionalIncludeDirectories>%(AdditionalIncludeDirectories)</AdditionalIncludeDirectories>
#     </ClCompile>
#   </ItemDefinitionGroup>
#   <ItemDefinitionGroup Condition="'$(Configuration)|$(Platform)'=='Release|x64'">
#     <Midl>
#       <TargetEnvironment>X64</TargetEnvironment>
#     </Midl>
#     <ClCompile>
#       <AdditionalIncludeDirectories>%(AdditionalIncludeDirectories)</AdditionalIncludeDirectories>
#     </ClCompile>
#   </ItemDefinitionGroup>
#   <ItemDefinitionGroup Condition="'$(Configuration)|$(Platform)'=='PGInstrument|Win32'">
#     <ClCompile>
#       <AdditionalIncludeDirectories>%(AdditionalIncludeDirectories)</AdditionalIncludeDirectories>
#     </ClCompile>
#   </ItemDefinitionGroup>
#   <ItemDefinitionGroup Condition="'$(Configuration)|$(Platform)'=='PGInstrument|x64'">
#     <Midl>
#       <TargetEnvironment>X64</TargetEnvironment>
#     </Midl>
#     <ClCompile>
#       <AdditionalIncludeDirectories>%(AdditionalIncludeDirectories)</AdditionalIncludeDirectories>
#     </ClCompile>
#   </ItemDefinitionGroup>
#   <ItemDefinitionGroup Condition="'$(Configuration)|$(Platform)'=='PGUpdate|Win32'">
#     <ClCompile>
#       <AdditionalIncludeDirectories>%(AdditionalIncludeDirectories)</AdditionalIncludeDirectories>
#     </ClCompile>
#   </ItemDefinitionGroup>
#   <ItemDefinitionGroup Condition="'$(Configuration)|$(Platform)'=='PGUpdate|x64'">
#     <Midl>
#       <TargetEnvironment>X64</TargetEnvironment>
#     </Midl>
#     <ClCompile>
#       <AdditionalIncludeDirectories>%(AdditionalIncludeDirectories)</AdditionalIncludeDirectories>
#     </ClCompile>
#   </ItemDefinitionGroup>
#   <ItemGroup>
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\arrayobject.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\arrayscalars.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\halffloat.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\ndarrayobject.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\ndarraytypes.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\noprefix.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\npy_1_7_deprecated_api.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\npy_3kcompat.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\npy_common.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\npy_cpu.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\npy_endian.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\npy_interrupt.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\npy_math.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\npy_no_deprecated_api.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\npy_os.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\numpyconfig.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\oldnumeric.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\old_defines.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\ufuncobject.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\utils.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\_neighborhood_iterator_imp.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\_numpyconfig.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\__multiarray_api.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\alloc.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\arrayobject.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\arraytypes.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\array_assign.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\buffer.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\calculation.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\cblasfuncs.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\common.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\compiled_base.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\conversion_utils.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\convert.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\convert_datatype.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\ctors.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\datetime_busday.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\datetime_busdaycal.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\datetime_strings.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\descriptor.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\getset.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\hashdescr.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\item_selection.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\iterators.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\mapping.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\methods.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\multiarraymodule.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\nditer_impl.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\nditer_pywrap.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\number.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\numpymemoryview.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\numpyos.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\refcount.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\scalartypes.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\sequence.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\shape.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\ucsnarrow.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\usertypes.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\vdot.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\_datetime.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\npymath\npy_math_common.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\npymath\npy_math_private.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\npysort\npysort_common.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\private\lowlevel_strided_loops.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\private\npy_cblas.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\private\npy_config.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\private\npy_fpmath.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\private\npy_import.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\private\npy_pycompat.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\private\npy_sort.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\private\ufunc_override.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\umath\reduction.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\umath\ufunc_object.h" />
#     <ClInclude Include="$(numpyDir)\numpy\core\src\umath\ufunc_type_resolution.h" />
#     <ClInclude Include="$(numpyDir)\numpy\fft\fftpack.h" />
#     <ClInclude Include="$(numpyDir)\numpy\linalg\lapack_lite\f2c.h" />
#     <ClInclude Include="$(numpyDir)\numpy\random\mtrand\distributions.h" />
#     <ClInclude Include="$(numpyDir)\numpy\random\mtrand\initarray.h" />
#     <ClInclude Include="$(numpyDir)\numpy\random\mtrand\mtrand_py_helper.h" />
#     <ClInclude Include="$(numpyDir)\numpy\random\mtrand\randomkit.h" />
#   </ItemGroup>
#   <ItemGroup>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\dummymodule.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\alloc.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\arrayobject.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\array_assign.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\array_assign_array.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\array_assign_scalar.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\buffer.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\calculation.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\cblasfuncs.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\common.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\compiled_base.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\conversion_utils.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\convert.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\convert_datatype.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\ctors.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\datetime.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\datetime_busday.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\datetime_busdaycal.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\datetime_strings.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\descriptor.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\dtype_transfer.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\flagsobject.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\getset.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\hashdescr.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\item_selection.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\iterators.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\mapping.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\methods.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\multiarraymodule.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\nditer_api.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\nditer_constr.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\nditer_pywrap.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\number.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\numpymemoryview.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\numpyos.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\python_xerbla.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\refcount.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\scalarapi.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\sequence.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\shape.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\ucsnarrow.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\usertypes.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\vdot.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\npymath\halffloat.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\npymath\_signbit.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\umath\reduction.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\umath\ufunc_object.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\umath\ufunc_type_resolution.c" />
#     <ClCompile Include="$(numpyDir)\numpy\core\src\umath\umathmodule.c" />
#     <ClCompile Include="$(numpyDir)\numpy\fft\fftpack.c" />
#     <ClCompile Include="$(numpyDir)\numpy\fft\fftpack_litemodule.c" />
#     <ClCompile Include="$(numpyDir)\numpy\linalg\lapack_litemodule.c" />
#     <ClCompile Include="$(numpyDir)\numpy\linalg\lapack_lite\blas_lite.c" />
#     <ClCompile Include="$(numpyDir)\numpy\linalg\lapack_lite\dlamch.c" />
#     <ClCompile Include="$(numpyDir)\numpy\linalg\lapack_lite\dlapack_lite.c" />
#     <ClCompile Include="$(numpyDir)\numpy\linalg\lapack_lite\f2c_lite.c" />
#     <ClCompile Include="$(numpyDir)\numpy\linalg\lapack_lite\python_xerbla.c" />
#     <ClCompile Include="$(numpyDir)\numpy\linalg\lapack_lite\zlapack_lite.c" />
#     <ClCompile Include="$(numpyDir)\numpy\random\mtrand\distributions.c" />
#     <ClCompile Include="$(numpyDir)\numpy\random\mtrand\initarray.c" />
#     <ClCompile Include="$(numpyDir)\numpy\random\mtrand\mtrand.c" />
#     <ClCompile Include="$(numpyDir)\numpy\random\mtrand\randomkit.c" />
#   </ItemGroup>
#   <ItemGroup>
#     <None Include="$(numpyDir)\numpy\core\code_generators\cversions.txt" />
#     <None Include="$(numpyDir)\numpy\ma\API_CHANGES.txt" />
#     <None Include="$(numpyDir)\numpy\ma\README.txt" />
#   </ItemGroup><ItemGroup>
#     <ProjectReference Include="pythoncore.vcxproj">
#       <Project>{cf7ac3d1-e2df-41d2-bea6-1e2556cdea26}</Project>
#     </ProjectReference>
#   </ItemGroup>
#   <Import Project="$(VCTargetsPath)\Microsoft.Cpp.targets" />
#   <ImportGroup Label="ExtensionTargets">
#   </ImportGroup>
# </Project>

# %%
print(p.vcxproj_filters)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <Project ToolsVersion="4.0" xmlns="http://schemas.microsoft.com/developer/msbuild/2003">
#   <ItemGroup>
#     <Filter Include="Source">
#       <UniqueIdentifier>{9D966219-0FD0-11E5-A785-8863DFCA3C40}</UniqueIdentifier>
#     </Filter>
#     <Filter Include="Headers">
#       <UniqueIdentifier>{9D96621A-0FD0-11E5-A2A8-8863DFCA3C40}</UniqueIdentifier>
#     </Filter>
#     <Filter Include="Python">
#       <UniqueIdentifier>{9D96621C-0FD0-11E5-9053-8863DFCA3C40}</UniqueIdentifier>
#     </Filter>
#     <Filter Include="Cython">
#       <UniqueIdentifier>{9D96621D-0FD0-11E5-B424-8863DFCA3C40}</UniqueIdentifier>
#     </Filter>
#     <Filter Include="Other">
#       <UniqueIdentifier>{9D96621B-0FD0-11E5-A79E-8863DFCA3C40}</UniqueIdentifier>
#     </Filter>
#   </ItemGroup>
#   <ItemGroup>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\dummymodule.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\alloc.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\arrayobject.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\array_assign.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\array_assign_array.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\array_assign_scalar.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\buffer.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\calculation.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\cblasfuncs.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\common.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\compiled_base.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\conversion_utils.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\convert.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\convert_datatype.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\ctors.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\datetime.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\datetime_busday.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\datetime_busdaycal.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\datetime_strings.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\descriptor.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\dtype_transfer.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\flagsobject.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\getset.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\hashdescr.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\item_selection.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\iterators.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\mapping.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\methods.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\multiarraymodule.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\nditer_api.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\nditer_constr.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\nditer_pywrap.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\number.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\numpymemoryview.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\numpyos.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\python_xerbla.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\refcount.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\scalarapi.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\sequence.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\shape.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\ucsnarrow.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\usertypes.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\multiarray\vdot.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\npymath\halffloat.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\npymath\_signbit.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\umath\reduction.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\umath\ufunc_object.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\umath\ufunc_type_resolution.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\core\src\umath\umathmodule.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\fft\fftpack.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\fft\fftpack_litemodule.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\linalg\lapack_litemodule.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\linalg\lapack_lite\blas_lite.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\linalg\lapack_lite\dlamch.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\linalg\lapack_lite\dlapack_lite.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\linalg\lapack_lite\f2c_lite.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\linalg\lapack_lite\python_xerbla.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\linalg\lapack_lite\zlapack_lite.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\random\mtrand\distributions.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\random\mtrand\initarray.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\random\mtrand\mtrand.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#     <ClCompile Include="$(numpyDir)\numpy\random\mtrand\randomkit.c">
#       <Filter>Source</Filter>
#     </ClCompile>
#   </ItemGroup>
#   <ItemGroup>
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\arrayobject.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\arrayscalars.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\halffloat.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\ndarrayobject.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\ndarraytypes.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\noprefix.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\npy_1_7_deprecated_api.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\npy_3kcompat.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\npy_common.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\npy_cpu.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\npy_endian.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\npy_interrupt.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\npy_math.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\npy_no_deprecated_api.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\npy_os.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\numpyconfig.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\oldnumeric.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\old_defines.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\ufuncobject.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\utils.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\_neighborhood_iterator_imp.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\_numpyconfig.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\include\numpy\__multiarray_api.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\alloc.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\arrayobject.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\arraytypes.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\array_assign.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\buffer.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\calculation.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\cblasfuncs.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\common.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\compiled_base.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\conversion_utils.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\convert.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\convert_datatype.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\ctors.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\datetime_busday.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\datetime_busdaycal.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\datetime_strings.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\descriptor.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\getset.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\hashdescr.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\item_selection.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\iterators.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\mapping.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\methods.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\multiarraymodule.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\nditer_impl.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\nditer_pywrap.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\number.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\numpymemoryview.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\numpyos.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\refcount.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\scalartypes.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\sequence.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\shape.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\ucsnarrow.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\usertypes.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\vdot.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\multiarray\_datetime.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\npymath\npy_math_common.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\npymath\npy_math_private.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\npysort\npysort_common.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\private\lowlevel_strided_loops.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\private\npy_cblas.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\private\npy_config.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\private\npy_fpmath.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\private\npy_import.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\private\npy_pycompat.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\private\npy_sort.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\private\ufunc_override.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\umath\reduction.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\umath\ufunc_object.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\core\src\umath\ufunc_type_resolution.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\fft\fftpack.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\linalg\lapack_lite\f2c.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\random\mtrand\distributions.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\random\mtrand\initarray.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\random\mtrand\mtrand_py_helper.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#     <ClInclude Include="$(numpyDir)\numpy\random\mtrand\randomkit.h">
#       <Filter>Headers</Filter>
#     </ClInclude>
#   </ItemGroup>
#   <ItemGroup>
#     <None Include="$(numpyDir)\numpy\add_newdocs.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\ctypeslib.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\dual.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\matlib.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\setup.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\version.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\_import_tools.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\__init__.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\build_utils\apple_accelerate.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\build_utils\common.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\build_utils\waf.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\build_utils\__init__.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\compat\py3k.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\compat\setup.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\compat\_inspect.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\compat\__init__.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\core\arrayprint.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\core\cversions.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\core\defchararray.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\core\fromnumeric.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\core\function_base.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\core\getlimits.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\core\info.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\core\machar.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\core\memmap.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\core\numeric.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\core\numerictypes.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\core\records.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\core\setup.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\core\setup_common.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\core\shape_base.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\core\_internal.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\core\_methods.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\core\__init__.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\core\code_generators\genapi.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\core\code_generators\generate_numpy_api.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\core\code_generators\generate_ufunc_api.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\core\code_generators\generate_umath.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\core\code_generators\numpy_api.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\core\code_generators\ufunc_docstrings.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\core\code_generators\__init__.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\doc\basics.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\doc\broadcasting.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\doc\byteswapping.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\doc\constants.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\doc\creation.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\doc\glossary.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\doc\howtofind.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\doc\indexing.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\doc\internals.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\doc\io.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\doc\jargon.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\doc\methods_vs_functions.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\doc\misc.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\doc\performance.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\doc\structured_arrays.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\doc\subclassing.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\doc\ufuncs.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\doc\__init__.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\fft\fftpack.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\fft\helper.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\fft\info.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\fft\setup.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\fft\__init__.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\lib\arraypad.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\lib\arraysetops.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\lib\arrayterator.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\lib\financial.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\lib\format.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\lib\function_base.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\lib\index_tricks.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\lib\info.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\lib\nanfunctions.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\lib\npyio.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\lib\polynomial.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\lib\recfunctions.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\lib\scimath.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\lib\setup.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\lib\shape_base.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\lib\stride_tricks.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\lib\twodim_base.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\lib\type_check.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\lib\ufunclike.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\lib\user_array.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\lib\utils.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\lib\_datasource.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\lib\_iotools.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\lib\_version.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\lib\__init__.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\linalg\info.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\linalg\linalg.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\linalg\setup.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\linalg\__init__.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\linalg\lapack_lite\clapack_scrub.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\linalg\lapack_lite\fortran.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\linalg\lapack_lite\make_lite.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\ma\bench.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\ma\core.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\ma\extras.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\ma\mrecords.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\ma\setup.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\ma\testutils.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\ma\timer_comparison.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\ma\version.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\ma\__init__.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\matrixlib\defmatrix.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\matrixlib\setup.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\matrixlib\__init__.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\polynomial\chebyshev.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\polynomial\hermite.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\polynomial\hermite_e.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\polynomial\laguerre.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\polynomial\legendre.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\polynomial\polynomial.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\polynomial\polyutils.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\polynomial\setup.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\polynomial\_polybase.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\polynomial\__init__.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\random\info.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\random\setup.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\random\__init__.py">
#       <Filter>Python</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\random\mtrand\generate_mtrand_c.py">
#       <Filter>Python</Filter>
#     </None>
#   </ItemGroup>
#   <ItemGroup>
#     <None Include="$(numpyDir)\numpy\random\mtrand\mtrand.pyx">
#       <Filter>Cython</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\random\mtrand\numpy.pxd">
#       <Filter>Cython</Filter>
#     </None>
#   </ItemGroup>
#   <ItemGroup>
#     <None Include="$(numpyDir)\numpy\core\code_generators\cversions.txt">
#       <Filter>Other</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\ma\API_CHANGES.txt">
#       <Filter>Other</Filter>
#     </None>
#     <None Include="$(numpyDir)\numpy\ma\README.txt">
#       <Filter>Other</Filter>
#     </None>
#   </ItemGroup>
# </Project>

# %%
print(p.compiles_props)

# %%
print(p.props)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <Project DefaultTargets="Build" ToolsVersion="4.0" xmlns="http://schemas.microsoft.com/developer/msbuild/2003">
#   <PropertyGroup>
#     <_ProjectFileVersion>10.0.30319.1</_ProjectFileVersion>
#   </PropertyGroup>
#   <ItemDefinitionGroup>
#     <ClCompile>
#       <AdditionalIncludeDirectories>$(numpyDir)\numpy\core\include;$(numpyDir)\build\src.win-amd64-3.3\numpy\core\include;$(numpyDir)\build\src.win-amd64-3.3\numpy\core\include\numpy;$(numpyDir)\numpy\core\src\private;$(numpyDir)\numpy\core\src;$(numpyDir)\numpy\core;$(numpyDir)\numpy\core\src\npymath;$(numpyDir)\numpy\core\src\multiarray;$(numpyDir)\numpy\core\src\umath;$(numpyDir)\numpy\core\src\npysort;$(numpyDir)\build\src.win-amd64-3.3\numpy\core\include;$(numpyDir)\build\src.win-amd64-3.3\numpy\core\src\private;$(numpyDir)\build\src.win-amd64-3.3\numpy\core\src;$(numpyDir)\build\src.win-amd64-3.3\numpy\core;$(numpyDir)\build\src.win-amd64-3.3\numpy\core\src\npymath;$(numpyDir)\build\src.win-amd64-3.3\numpy\core\src\multiarray;$(numpyDir)\build\src.win-amd64-3.3\numpy\core\src\umath;$(numpyDir)\build\src.win-amd64-3.3\numpy\core\src\npysort</AdditionalIncludeDirectories>
#     </ClCompile>
#     <ResourceCompile>
#       <PreprocessorDefinitions>NUMPY_VERSION=1.9.2;NUMPY_MICRO=2;NUMPY_MAJOR=1;NUMPY_MINOR=9;NUMPY_BUILD=0;%(PreprocessorDefinitions)</PreprocessorDefinitions>
#     </ResourceCompile>
#   </ItemDefinitionGroup>
# </Project>

# %%
print(p.props_debug)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <Project DefaultTargets="Build" ToolsVersion="4.0" xmlns="http://schemas.microsoft.com/developer/msbuild/2003">
#   <PropertyGroup>
#     <_ProjectFileVersion>10.0.30319.1</_ProjectFileVersion>
#   </PropertyGroup>
#   <ItemDefinitionGroup>
#     <ClCompile>
#       <AdditionalIncludeDirectories>$(numpyDir)\numpy\core\include;$(numpyDir)\build\src.win-amd64-3.3\numpy\core\include;$(numpyDir)\build\src.win-amd64-3.3\numpy\core\include\numpy;$(numpyDir)\numpy\core\src\private;$(numpyDir)\numpy\core\src;$(numpyDir)\numpy\core;$(numpyDir)\numpy\core\src\npymath;$(numpyDir)\numpy\core\src\multiarray;$(numpyDir)\numpy\core\src\umath;$(numpyDir)\numpy\core\src\npysort;$(numpyDir)\build\src.win-amd64-3.3\numpy\core\include;$(numpyDir)\build\src.win-amd64-3.3\numpy\core\src\private;$(numpyDir)\build\src.win-amd64-3.3\numpy\core\src;$(numpyDir)\build\src.win-amd64-3.3\numpy\core;$(numpyDir)\build\src.win-amd64-3.3\numpy\core\src\npymath;$(numpyDir)\build\src.win-amd64-3.3\numpy\core\src\multiarray;$(numpyDir)\build\src.win-amd64-3.3\numpy\core\src\umath;$(numpyDir)\build\src.win-amd64-3.3\numpy\core\src\npysort</AdditionalIncludeDirectories>
#     </ClCompile>
#     <ResourceCompile>
#       <PreprocessorDefinitions>NUMPY_VERSION=1.9.2;NUMPY_MICRO=2;NUMPY_MAJOR=1;NUMPY_MINOR=9;NUMPY_BUILD=0;%(PreprocessorDefinitions)</PreprocessorDefinitions>
#     </ResourceCompile>
#   </ItemDefinitionGroup>
# </Project>

# %%
p.write()
# Out:
# wrote C:\Users\Trent\Home\src\pyparallel\PCbuild\numpy.vcxproj
# wrote C:\Users\Trent\Home\src\pyparallel\PCbuild\numpy.vcxproj.filters
# wrote C:\Users\Trent\Home\src\pyparallel\PCbuild\numpy.props
# wrote C:\Users\Trent\Home\src\pyparallel\PCbuild\numpy_debug.props

# %% [markdown]
# Add pyodbc.vcxproj to pcbuild.sln in Visual Studio.
